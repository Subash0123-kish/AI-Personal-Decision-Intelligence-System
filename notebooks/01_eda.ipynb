# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook provides interactive exploration of your data.
#
# ## Steps:
# 1. Load your data
# 2. Explore distributions
# 3. Analyze correlations
# 4. Identify patterns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

# Add src to path
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))

from eda_utils import EDAUtils

# Set style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 8)

# %%
# Load your data
df = pd.read_csv('../data/raw/user_data.csv')
df.head()

# %%
# Basic statistics
eda = EDAUtils()
stats = eda.get_basic_stats(df)
print(stats)

# %%
# Missing values
missing = eda.get_missing_info(df)
print(missing)

# %%
# Correlation matrix
fig = eda.plot_correlation_matrix(df)
plt.show()

# %%
# Distributions
fig = eda.plot_distributions(df)
plt.show()

# %%
# Target analysis (if target column exists)
target_col = 'investment_success'  # Change to your target column
if target_col in df.columns:
    fig = eda.plot_target_analysis(df, target_col)
    plt.show()
